# %% [markdown]
# # Import dataset

# %%
import pandas as pd
A = pd.read_csv("C:/users/HP/Downloads/Cars93.csv")

from warnings import filterwarnings
filterwarnings("ignore")

# %%
A.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             93 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
A.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
A.shape
# Out:
# (93, 28)

# %% [markdown]
# # Data preprocessing

# %%
import missingno as mo

# %%
mo.bar(A) #finding out missing vaalue in dataset in graphical form using missingno library
# Out:
# <AxesSubplot:>

# %%
A.isna().sum().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#separating the categorical and continuous column from the dataset
cat = []
con = []
for i in A.columns:
    if(A[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat #categorical columns
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con #continuous columns
# Out:
# ['Unnamed: 0',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
#treating missing values
def replacer(df):
    for i in con:
        x = df[i].mean()
        df[i] = df[i].fillna(x)
        
    for i in cat:
        x = df[i].mode()[0]
        df[i] = df[i].fillna(x)

# %%
replacer(A)

# %%
A.isna().sum() #All null values treated
# Out:
# Unnamed: 0            0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %%
A
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# # Univariate analysis of continuous columns

# %%
import seaborn as sb
sb.distplot(A.Passengers)
# Out:
# <AxesSubplot:xlabel='Passengers', ylabel='Density'>

# %% [markdown]
# The above graph represents displot of no. of passengers in each car.

# %%
import matplotlib.pyplot as plt
for i in con:
    sb.distplot(A[i])
    plt.show()

# %% [markdown]
# The above distplot represents spread of data in different continuous columns of dataset.

# %% [markdown]
# # Histogram of continuous columns

# %%
for i in con:
    plt.xlabel(i)
    A[i].hist()
    plt.show()

# %% [markdown]
# The above histogram represents frequency of data values in different continuous columns of dataset.

# %% [markdown]
# # Univariate analysis of categorical columns

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
for i in cat:
    sb.countplot(A[i])
    plt.show()

# %%
for i in cat:
    A[i].value_counts().plot(kind="barh")
    plt.show()

# %%
for i in cat:
    A[i].value_counts().plot(kind='pie')
    plt.show()

# %% [markdown]
# # Bivariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
A
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %%
for i in A.columns:
    if(A[i].dtypes == "object"):
        sb.boxplot(A[i],A.Width)#Boxplot between categorical and continuous columns
        plt.xlabel(i)
        plt.ylabel("Width")
        plt.show()
        
    else:
        plt.scatter(A[i],A.Width)#Scatter plot between continuous and continuous columns
        plt.xlabel(i)
        plt.ylabel("Width")
        plt.show()

# %%
A.corr() #Correlation between continuous columns
# Out:
#                     Unnamed: 0  Min.Price     Price  Max.Price  MPG.city  \
# Unnamed: 0            1.000000  -0.144463 -0.137277  -0.126567  0.161808
# Min.Price            -0.144463   1.000000  0.970601   0.906756 -0.622875
# Price                -0.137277   0.970601  1.000000   0.981580 -0.594562
# Max.Price            -0.126567   0.906756  0.981580   1.000000 -0.547811
# MPG.city              0.161808  -0.622875 -0.594562  -0.547811  1.000000
# MPG.highway           0.137317  -0.579966 -0.560680  -0.522561  0.943936
# EngineSize           -0.338286   0.645488  0.597425   0.535012 -0.710003
# Horsepower           -0.233012   0.802444  0.788218   0.744445 -0.672636
# RPM                   0.167772  -0.042598 -0.004955   0.025015  0.363045
# Rev.per.mile          0.226389  -0.470395 -0.426395  -0.374024  0.695857
# Fuel.tank.capacity   -0.179034   0.635369  0.619480   0.581294 -0.813144
# Passengers           -0.142252   0.061236  0.057860   0.053216 -0.416856
# ...

# %%
for i in A.columns:
    if(A[i].dtypes == "object"):
        sb.countplot(A.Origin,hue=A[i])#Countplot with hue between categorical and categorical columns
        plt.xlabel(i)
        plt.show()

# %%
pd.crosstab(A.Origin,A.Type)#Crosstab between categorical and categorical columns
# Out:
# Type     Compact  Large  Midsize  Small  Sporty  Van
# Origin
# USA            7     11       10      7       8    5
# non-USA        9      0       12     14       6    4

# %%
pd.crosstab(A.Origin,A.AirBags)
# Out:
# AirBags  Driver & Passenger  Driver only  None
# Origin
# USA                       9           23    16
# non-USA                   7           20    18

# %%
pd.crosstab(A.Origin,A.DriveTrain)
# Out:
# DriveTrain  4WD  Front  Rear
# Origin
# USA           5     34     9
# non-USA       5     33     7

# %%
pd.crosstab(A.Origin,A.Cylinders)
# Out:
# Cylinders  3   4  5   6  8  rotary
# Origin
# USA        0  22  0  20  6       0
# non-USA    3  27  2  11  1       1

# %%
pd.crosstab(A.Origin,A['Man.trans.avail'])
# Out:
# Man.trans.avail  No  Yes
# Origin
# USA              26   22
# non-USA           6   39

# %%
sb.pairplot(A)#Pair Plots way to visualize relationships between each variable

# %%
sb.heatmap(A.corr()) #Correlation between continuous columns represented by ploting heat map
# Out:
# <AxesSubplot:>
